# %% [markdown]
# ## Practice problem 1

# %%
import pandas as pd
import matplotlib.pyplot as plt 
from io import StringIO
import warnings
warnings.filterwarnings('ignore')

data = """EmployeeID,EmployeeName,Age,Salary,Price,Marks1,Marks2,Marks3
E101,Alice,25,50000,1200,85,90,88
E102,Bob,30,,1500,78,82,80
E103,Charlie,22,52000,1100,92,95,90
E101,Alice,25,50000,1200,85,90,88
E104,David,45,80000,2500,88,85,89
E105,Eve,29,58000,1300,76,79,81
E106,Frank,,75000,2200,90,91,92
E107,Grace,34,,1900,81,83,80
E108,Heidi,38,,1800,84,86,88
E109,Ivan,26,53000,1400,95,92,94
E102,Bob,30,,1500,78,82,80
"""

df = pd.read_csv(StringIO(data))
print(df)
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0      NaN   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0      NaN   1500      78      82      80

# %%
df['Discount_Price']=df['Price']-(df['Price']/10)

# %%
df.head()
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0      NaN   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 3       E101        Alice  25.0  50000.0   1200      85      90      88
# 4       E104        David  45.0  80000.0   2500      88      85      89
#
#    Discount_Price
# 0          1080.0
# 1          1350.0
# 2           990.0
# 3          1080.0
# 4          2250.0

# %%
df.to_csv('discounted_products.csv',index=False)

# %% [markdown]
# ## Practice Problem 2

# %%
df['EmployeeID'].duplicated().sum()
# Out:
# np.int64(2)

# %%
df_cleaned = df.drop_duplicates(subset='EmployeeID',keep='first')

# %%
df_cleaned
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0      NaN   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 4       E104        David  45.0  80000.0   2500      88      85      89
# 5       E105          Eve  29.0  58000.0   1300      76      79      81
# 6       E106        Frank   NaN  75000.0   2200      90      91      92
# 7       E107        Grace  34.0      NaN   1900      81      83      80
# 8       E108        Heidi  38.0      NaN   1800      84      86      88
# 9       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Discount_Price
# 0          1080.0
# 1          1350.0
# 2           990.0
# 4          2250.0
# 5          1170.0
# 6          1980.0
# 7          1710.0
# 8          1620.0
# 9          1260.0

# %%
df_cleaned['EmployeeID'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Practice Problem 3

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Salary'].isnull().sum()
# Out:
# np.int64(4)

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0      NaN   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank  30.4  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0      NaN   1500      78      82      80
#
#     Discount_Price
# 0           1080.0
# 1           1350.0
# 2            990.0
# ...

# %%
df = df.dropna(subset=['Salary'])

# %%
df
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 3       E101        Alice  25.0  50000.0   1200      85      90      88
# 4       E104        David  45.0  80000.0   2500      88      85      89
# 5       E105          Eve  29.0  58000.0   1300      76      79      81
# 6       E106        Frank  30.4  75000.0   2200      90      91      92
# 9       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Discount_Price
# 0          1080.0
# 2           990.0
# 3          1080.0
# 4          2250.0
# 5          1170.0
# 6          1980.0
# 9          1260.0

# %% [markdown]
# ## Problem Solving 4

# %%
print(df['Marks1'].mean())
print(df['Marks2'].mean())
print(df['Marks3'].mean())
# Out:
# 87.28571428571429
# 88.85714285714286
# 88.85714285714286

# %%
df['Total_mark']=df['Marks1']+df['Marks2']+df['Marks3']

# %%
df.head()
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 3       E101        Alice  25.0  50000.0   1200      85      90      88
# 4       E104        David  45.0  80000.0   2500      88      85      89
# 5       E105          Eve  29.0  58000.0   1300      76      79      81
#
#    Discount_Price  Total_mark
# 0          1080.0         263
# 2           990.0         277
# 3          1080.0         263
# 4          2250.0         262
# 5          1170.0         236

# %%
df['Std_total'] = df['Total_mark'].std()

# %%
df.head()
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 3       E101        Alice  25.0  50000.0   1200      85      90      88
# 4       E104        David  45.0  80000.0   2500      88      85      89
# 5       E105          Eve  29.0  58000.0   1300      76      79      81
#
#    Discount_Price  Total_mark  Std_total
# 0          1080.0         263  14.843629
# 2           990.0         277  14.843629
# 3          1080.0         263  14.843629
# 4          2250.0         262  14.843629
# 5          1170.0         236  14.843629

# %% [markdown]
# ## Practice Problem 5

# %%
# plt.xlabel("AGE")
# plt.ylabel('FREQUENCY')
plt.hist(df['Age'])
plt.grid()
plt.show()

# %%
plt.xlabel("AGE")
plt.ylabel('FREQUENCY')
plt.title('Relation between age & salary')
plt.grid()
plt.scatter(df['Age'],df['Salary'])
plt.show()

# %%
plt.xlabel("Price")
plt.ylabel('Discount Price')
plt.title('Relation between price & Discount Price')
plt.scatter(df['Price'],df['Discount_Price'])
plt.grid()
plt.show()
