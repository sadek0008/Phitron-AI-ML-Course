# %%
import matplotlib.pyplot as plt

s1 = [2,3,4,5,6,7,1,2]
s2 = [9,1,4,3,2,9,6,3]
days = [1,2,3,4,5,6,7,8]

plt.plot(days,s1)

# %%
plt.title('Study Time Graph')
plt.xlabel("hours")
plt.ylabel("days")
plt.plot(days,s1)
plt.plot(days,s2)
